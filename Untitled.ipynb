# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.ticker as ticker
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('for_EDA_fixed.csv', encoding='utf-8')
data
# Out:
#                                     Title  Original Price  Discounted Price  \
# 0                         Baldur's Gate 3           29.99             29.99
# 1        Counter-Strike: Global Offensive           14.99             14.99
# 2                           Apex Legends™            0.00              0.00
# 3                         Forza Horizon 5           34.78             17.39
# 4                           Call of Duty®            0.00              0.00
# ...                                   ...             ...               ...
# 71695                           The Front            0.00              0.00
# 71696                        The Bornless            0.00              0.00
# 71697                     Winter Memories            0.00              0.00
# 71698  Call of Duty®: Modern Warfare® III           69.99             69.99
# 71699            Pixel Gun 3D: PC Edition            0.00              0.00
#
#        Price Difference  Release Date  \
# ...

# %%
correlation_matrix = data.corr(numeric_only=True)
correlation_matrix
# Out:
#                     Original Price  Discounted Price  Price Difference  \
# Original Price            1.000000          0.999953          0.999991
# Discounted Price          0.999953          1.000000          0.999905
# Price Difference          0.999991          0.999905          1.000000
# Release Date             -0.001012         -0.000969         -0.001031
# Reviews_number            0.009123          0.025858         -0.002969
# Reviews_percentage       -0.022843          0.016513         -0.034401
# Memory                   -0.000022         -0.000023         -0.000022
#
#                     Release Date  Reviews_number  Reviews_percentage    Memory
# Original Price         -0.001012        0.009123           -0.022843 -0.000022
# Discounted Price       -0.000969        0.025858            0.016513 -0.000023
# Price Difference       -0.001031       -0.002969           -0.034401 -0.000022
# Release Date            1.000000       -0.052814            0.158993  0.005406
# ...

# %%
data.describe()
# Out:
#        Original Price  Discounted Price  Price Difference  Release Date  \
# count    7.170000e+04      7.170000e+04      7.170000e+04  61492.000000
# mean     5.943817e+02      1.821652e+02      4.122165e+02   2019.433813
# std      9.085764e+04      2.725962e+04      6.359983e+04      2.919596
# min      0.000000e+00      0.000000e+00      0.000000e+00   1969.000000
# 25%      7.900000e-01      3.400000e-01      0.000000e+00   2018.000000
# 50%      2.790000e+00      2.690000e+00      0.000000e+00   2020.000000
# 75%      6.290000e+00      6.290000e+00      0.000000e+00   2022.000000
# max      1.404633e+07      4.213900e+06      9.832433e+06   2023.000000
#
#        Reviews_number  Reviews_percentage        Memory
# count    37481.000000        37481.000000  6.554300e+04
# mean       201.664603           76.729436  1.489957e+11
# std       1771.148316           18.005781  3.814494e+13
# min         10.000000            0.000000  0.000000e+00
# ...

# %%
numeric_columns = data.select_dtypes(include=np.number)

has_inf = np.isinf(numeric_columns).any().any()

if has_inf:
    print("DataFrame contains infinite values.")
else:
    print("DataFrame does not contain infinite values.")
# Out:
# DataFrame does not contain infinite values.

# %% [markdown]
# ### Limpieza de Datos

# %%
data.isnull().sum()
# Out:
# Title                       1
# Original Price              0
# Discounted Price            0
# Price Difference            0
# Release Date            10208
# Game Description          211
# Reviews Summary         34219
# Reviews_number          34219
# Reviews_percentage      34219
# Developer                 221
# Publisher                 517
# Supported Languages         0
# Popular Tags                0
# Game Features               0
# Minimum Requirements     2337
# Link                        0
# Processor                6327
# Memory                   6157
# Graphics                11038
# DirectX                 35250
# Storage                  7560
# dtype: int64

# %% [markdown]
# **Title**
# Empecemos por la columna Título. Sabiendo que ya hemos manejado sólo un valor de nan en la columna título, es raro que aún lo veamos aquí.

# %%
print(data[data['Title'].isna()]['Game Description'])
data[data['Title'].isna()]
# Out:
# 56954    NaN
# Name: Game Description, dtype: object
#       Title  Original Price  Discounted Price  Price Difference  Release Date  \
# 56954   NaN             0.0               0.0               0.0           NaN
#
#       Game Description Reviews Summary  Reviews_number  Reviews_percentage  \
# 56954              NaN             NaN             NaN                 NaN
#
#       Developer  ... Supported Languages Popular Tags Game Features  \
# 56954       NaN  ...                  []           []            []
#
#       Minimum Requirements                                               Link  \
# 56954                  NaN  https://store.steampowered.com/sub/418/?snr=1_...
#
#       Processor Memory  Graphics DirectX Storage
# 56954       NaN    NaN       NaN     NaN     NaN
#
# [1 rows x 21 columns]

# %%
data.loc[56954, 'Title'] = 'Unknown'
data.loc[56954]
# Out:
# Title                                                             Unknown
# Original Price                                                        0.0
# Discounted Price                                                      0.0
# Price Difference                                                      0.0
# Release Date                                                          NaN
# Game Description                                                      NaN
# Reviews Summary                                                       NaN
# Reviews_number                                                        NaN
# Reviews_percentage                                                    NaN
# Developer                                                             NaN
# Publisher                                                             NaN
# Supported Languages                                                    []
# Popular Tags                                                           []
# ...
