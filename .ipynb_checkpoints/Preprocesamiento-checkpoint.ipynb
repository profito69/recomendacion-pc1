# %%
import pandas as pd
import numpy as np
from datetime import datetime
import ast
import re
import warnings

# %%
df = pd.read_csv(r'merged_data.csv')

# %%
df.head(5)
# Out:
#                               Title Original Price Discounted Price  \
# 0                   Baldur's Gate 3         $29.99           $29.99
# 1  Counter-Strike: Global Offensive         $14.99           $14.99
# 2                     Apex Legends™           Free             Free
# 3                   Forza Horizon 5         $34.78           $17.39
# 4                     Call of Duty®           Free             Free
#
#    Release Date                                               Link  \
# 0   3 Aug, 2023  https://store.steampowered.com/app/1086940/Bal...
# 1  21 Aug, 2012  https://store.steampowered.com/app/730/Counter...
# 2   4 Nov, 2020  https://store.steampowered.com/app/1172470/Ape...
# 3   8 Nov, 2021  https://store.steampowered.com/app/1551360/For...
# 4  27 Oct, 2022  https://store.steampowered.com/app/1938090/Cal...
#
#                                     Game Description   Recent Reviews Summary  \
# ...

# %%
link_column = df['Link']

df = df.drop(columns=['Link'])

df['Link'] = link_column
df
# Out:
#                                     Title Original Price Discounted Price  \
# 0                         Baldur's Gate 3         $29.99           $29.99
# 1        Counter-Strike: Global Offensive         $14.99           $14.99
# 2                           Apex Legends™           Free             Free
# 3                         Forza Horizon 5         $34.78           $17.39
# 4                           Call of Duty®           Free             Free
# ...                                   ...            ...              ...
# 71695                           The Front           Free             Free
# 71696                        The Bornless           Free             Free
# 71697                     Winter Memories           Free             Free
# 71698  Call of Duty®: Modern Warfare® III         $69.99           $69.99
# 71699            Pixel Gun 3D: PC Edition           Free             Free
#
#           Release Date                                   Game Description  \
# ...

# %% [markdown]
# ## Limpieza de datos para Fecha de Lanzamiento
# Definimos una función convert_release_date para limpiar y estandarizar datos string en una columna de un DatagFrame. Funciona para varios formatos de fecha y los convierte en años o en "Unknown" si estan después de una fecha determinada.

# %%
def convert_release_date(date_str):
    if pd.isnull(date_str) or date_str in ['Coming Soon', 'To be announced']:
        return date_str
    else:
        try:
            date = datetime.strptime(date_str, '%d %b, %Y')
            if date > datetime(2023, 8, 15):
                return "Unknown"
            else:
                return date.year
        except ValueError:
            try:
                return datetime.strptime(date_str, '%b %Y').year
            except ValueError:
                return date_str

# %%
df['Release Date'] = df['Release Date'].apply(convert_release_date)
df
# Out:
#                                     Title Original Price Discounted Price  \
# 0                         Baldur's Gate 3         $29.99           $29.99
# 1        Counter-Strike: Global Offensive         $14.99           $14.99
# 2                           Apex Legends™           Free             Free
# 3                         Forza Horizon 5         $34.78           $17.39
# 4                           Call of Duty®           Free             Free
# ...                                   ...            ...              ...
# 71695                           The Front           Free             Free
# 71696                        The Bornless           Free             Free
# 71697                     Winter Memories           Free             Free
# 71698  Call of Duty®: Modern Warfare® III         $69.99           $69.99
# 71699            Pixel Gun 3D: PC Edition           Free             Free
#
#           Release Date                                   Game Description  \
# ...

# %% [markdown]
# ## Convertir la columna precios a Numericos.
# Definimos una función convert_to_numeric para limpiar y convertir los valores.

# %%
def convert_to_numeric(value):
    try:
        cleaned_value = value.replace('$', '').replace(',', '').strip().lower()
        if cleaned_value in ['free', '0']:
            return 0
        return float(cleaned_value)
    except:
        return None  

df['Original Price'] = df['Original Price'].apply(convert_to_numeric)
df['Discounted Price'] = df['Discounted Price'].apply(convert_to_numeric)

df.insert(df.columns.get_loc('Discounted Price') + 1, 'Price Difference', df['Original Price'] - df['Discounted Price'])

# %%
df.isnull().sum()
# Out:
# Title                         1
# Original Price                0
# Discounted Price              0
# Price Difference              0
# Release Date                131
# Game Description            211
# Recent Reviews Summary    15220
# All Reviews Summary       66329
# Recent Reviews Number     15220
# All Reviews Number        66329
# Developer                   221
# Publisher                   517
# Supported Languages           0
# Popular Tags                  0
# Game Features                 0
# Minimum Requirements       1124
# Link                          0
# dtype: int64

# %% [markdown]
# ## Manejando los reviews vacíos
# Fusionar las columnas'Recent Reviews Number' y 'All Reviews Number' para obtener una nueva columna 'Reviews_number', priorizando reseñas recientes disponibles.

# %%
df['Recent_or_All_Reviews'] = np.where(
    df['Recent Reviews Number'].notna(),
    df['Recent Reviews Number'],
    df['All Reviews Number']
)

df.insert(df.columns.get_loc('All Reviews Number') + 1, 'Reviews_number', df['Recent_or_All_Reviews'])

df.drop(columns=['Recent_or_All_Reviews'], inplace=True)
